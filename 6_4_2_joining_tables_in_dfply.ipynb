# %% [markdown]
# # Joining Tables with `dfply`

# %%
import pandas as pd
from dfply import *

# %% [markdown]
# ## Hiding stack traceback
#
# We hide the exception traceback for didactic reasons (code source: [see this post](https://stackoverflow.com/questions/46222753/how-do-i-suppress-tracebacks-in-jupyter)).  Don't run this cell if you want to see a full traceback.

# %%
import sys
ipython = get_ipython()

def hide_traceback(exc_tuple=None, filename=None, tb_offset=None,
                   exception_only=False, running_compiled_code=False):
    etype, value, tb = sys.exc_info()
    return ipython._showtraceback(etype, value, ipython.InteractiveTB.get_exception_only(etype, value))

ipython.showtraceback = hide_traceback

# %% [markdown]
# ## Example
#
# The following tables were taken from the Wikipedia page for joins and will provide a small but sufficiently complicated example for introducing joins.

# %%
dept = pd.read_csv("./data/department.csv")
dept
# Out:
#    DeptID     DeptName
# 0      31        Sales
# 1      33  Engineering
# 2      34     Clerical
# 3      35    Marketing

# %%
empl = pd.read_csv("./data/employee.csv")
empl
# Out:
#      LastName  DeptID
# 0    Rafferty    31.0
# 1       Jones    33.0
# 2  Heisenberg    33.0
# 3    Robinson    34.0
# 4       Smith    34.0
# 5    Williams     NaN

# %% [markdown]
# ## Left Outer Join
#
# Use `left_table >> dfply.left_join(right_table, by=common_col_name)`

# %%
empl >> left_join(dept, by='DeptID')
# Out:
#      LastName  DeptID     DeptName
# 0    Rafferty    31.0        Sales
# 1       Jones    33.0  Engineering
# 2  Heisenberg    33.0  Engineering
# 3    Robinson    34.0     Clerical
# 4       Smith    34.0     Clerical
# 5    Williams     NaN          NaN

# %% [markdown]
# ## Rename when the column names are different

# %%
empl2 = empl.fillna(0) >> rename(deptIDL = 'DeptID') 
empl2
# Out:
#      LastName  deptIDL
# 0    Rafferty     31.0
# 1       Jones     33.0
# 2  Heisenberg     33.0
# 3    Robinson     34.0
# 4       Smith     34.0
# 5    Williams      0.0

# %%
empl2 >> left_join(dept, by='DeptID')
# Out:
# KeyError: 'DeptID'

# %%
empl2 >> rename(DeptID = 'deptIDL') >> left_join(dept, by='DeptID')
# Out:
#      LastName  DeptID     DeptName
# 0    Rafferty    31.0        Sales
# 1       Jones    33.0  Engineering
# 2  Heisenberg    33.0  Engineering
# 3    Robinson    34.0     Clerical
# 4       Smith    34.0     Clerical
# 5    Williams     0.0          NaN

# %% [markdown]
# ## Right Outer Join
#
# Use `right_table >> dfply.right_join(left_table, by=common_col_name)`

# %%
empl >> right_join(dept, by='DeptID')
# Out:
#      LastName  DeptID     DeptName
# 0    Rafferty    31.0        Sales
# 1       Jones    33.0  Engineering
# 2  Heisenberg    33.0  Engineering
# 3    Robinson    34.0     Clerical
# 4       Smith    34.0     Clerical
# 5         NaN    35.0    Marketing

# %% [markdown]
# ## Full Outer Join
#
# Use `left_table >> dfply.outer_join(right_table, by=common_col_name)`

# %%
empl >> outer_join(dept, by='DeptID')
# Out:
#      LastName  DeptID     DeptName
# 0    Rafferty    31.0        Sales
# 1       Jones    33.0  Engineering
# 2  Heisenberg    33.0  Engineering
# 3    Robinson    34.0     Clerical
# 4       Smith    34.0     Clerical
# 5    Williams     NaN          NaN
# 6         NaN    35.0    Marketing

# %% [markdown]
# ## Inner Join
#
# Use `left_table >> dfply.inner_join(right_table, by=common_col_name)`

# %%
empl >> inner_join(dept, by='DeptID')
# Out:
#      LastName  DeptID     DeptName
# 0    Rafferty    31.0        Sales
# 1       Jones    33.0  Engineering
# 2  Heisenberg    33.0  Engineering
# 3    Robinson    34.0     Clerical
# 4       Smith    34.0     Clerical

# %% [markdown]
# ## Example 2 - Joining Batting to People
#
# As an example of a joining on more than 1 column, consider the following task.
#
# **Task:** Create a table with the total runs score for each team in 2009.  Include the teams proper name and the name of their home park.

# %%
files = ("./data/baseball/core/Batting.csv", 
         "./data/baseball/core/Teams.csv")

# %%
batting, teams = [pd.read_csv(f) for f in files]

# %% [markdown]
# ## Things we need from `Batting.csv`
#
# * Year
# * Runs
# * Team

# %%
batting.head(2)
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0  8.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
#
# [2 rows x 22 columns]

# %% [markdown]
# #### Selecting down to the necessary columns

# %%
batting_select = (batting
                  >> select(X.teamID,
                            X.yearID,
                            X.R)
                 )
batting_select.head()
# Out:
#   teamID  yearID   R
# 0    TRO    1871   0
# 1    RC1    1871  30
# 2    CL1    1871  28
# 3    WS3    1871  28
# 4    RC1    1871  29

# %%
batting_select.shape
# Out:
# (107429, 3)

# %% [markdown]
# ## Things we need from `Teams.csv`
#
# * Year
# * Runs
# * Team

# %%
teams.head(2)
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
#
#                       name                     park  attendance  BPF  PPF  \
# 0     Boston Red Stockings      South End Grounds I         NaN  103   98
# 1  Chicago White Stockings  Union Base-Ball Grounds         NaN  104  102
#
#    teamIDBR  teamIDlahman45  teamIDretro
# 0       BOS             BS1          BS1
# 1       CHI             CH1          CH1
#
# [2 rows x 48 columns]

# %% [markdown]
# #### Selecting down to the necessary columns

# %%
teams_select = (teams >> select(X.yearID,
                                X.teamID,
                                X.name,
                                X.park))
teams_select.head()
# Out:
#    yearID teamID                     name                          park
# 0    1871    BS1     Boston Red Stockings           South End Grounds I
# 1    1871    CH1  Chicago White Stockings       Union Base-Ball Grounds
# 2    1871    CL1   Cleveland Forest Citys  National Association Grounds
# 3    1871    FW1     Fort Wayne Kekiongas                Hamilton Field
# 4    1871    NY2         New York Mutuals      Union Grounds (Brooklyn)

# %%
teams_select.shape
# Out:
# (2925, 4)

# %% [markdown]
# ## How can we match these columns?
#
# We will need to match on both `teamID` and `yearID` because
#
# 1. Team names might change
# 2. The teams park depends on the year.

# %% [markdown]
# ## Determining the correct join.
#
# Facts of the task:
#
# * We want batting statistics for all players in 2009
# * We want only teams names and parks for teams that played that year.
#
# **Question:** Which join?
# **Answer:** `batting >> left_join(teams)` on both year and

# %% [markdown]
# ## How to join on multiple columns
#
# Pass a list of columns names to `by`

# %%
df_joined = batting_select >> left_join(teams_select, by=['teamID', 'yearID'])
df_joined.head()
# Out:
#   teamID  yearID   R                    name  \
# 0    TRO    1871   0          Troy Haymakers
# 1    RC1    1871  30   Rockford Forest Citys
# 2    CL1    1871  28  Cleveland Forest Citys
# 3    WS3    1871  28     Washington Olympics
# 4    RC1    1871  29   Rockford Forest Citys
#
#                                 park
# 0                 Haymakers' Grounds
# 1  Agricultural Society Fair Grounds
# 2       National Association Grounds
# 3                   Olympics Grounds
# 4  Agricultural Society Fair Grounds

# %% [markdown]
# #### Filter, group by, and aggregate to get the desired result.

# %%
runs_per_team09 = (df_joined
                   >> filter_by(X.yearID == 2009)
                   >> group_by(X.name, X.park)
                   >> summarise(total_runs = X.R.sum()))
runs_per_team09.head()
# Out:
#                           park                  name  total_runs
# 0                  Chase Field  Arizona Diamondbacks         720
# 1                 Turner Field        Atlanta Braves         735
# 2  Oriole Park at Camden Yards     Baltimore Orioles         741
# 3               Fenway Park II        Boston Red Sox         872
# 4                Wrigley Field          Chicago Cubs         707

# %%
runs_per_team09.shape
# Out:
# (30, 3)

# %% [markdown]
# ## Joins are expensive!
#
# **Be careful when joining large tables!! Especially for full outer joins!!!**
#
# When joining table `A` to table `B`,
#
# * `inner_join` performs `min(len(A), len(B))` comparisons
# * `outer_join` performs `len(A)*len(B)` row comparisons.
# * `left_join` and `right_join` are somewhere inbetween (depending on how we treat multiples).

# %% [markdown]
# ## Outer joins (can) produce LARGE tables.
#
# **Be careful when joining large tables!! Especially for full outer joins!!!**
#
# When joining table `A` to table `B`,
#
# * `outer_join` might produce `len(A)*len(B)` rows (worst case)
# * `left_join` and `right_join` are similar if we don't drop multiples.

# %% [markdown]
# #### Last example

# %%
len(batting_select)*len(teams_select)
# Out:
# 314229825

# %% [markdown]
# ## The joining mantra: Filter/aggregate THEN join
#
# By filtering and/or aggregating before joining, you will
#
# * reduce the amount of work
# * protect against really large output

# %% [markdown]
# #### Filter and aggregate to total runs per team per year

# %%
runs = (batting_select
        >> filter_by(X.yearID == 2009)
        >> group_by(X.teamID)
        >> summarise(total_runs = X.R.sum()))

runs.head()
# Out:
#   teamID  total_runs
# 0    ARI         720
# 1    ATL         735
# 2    BAL         741
# 3    BOS         872
# 4    CHA         724

# %% [markdown]
# #### Filter down to 2009 teams

# %%
teams09 = (teams_select
           >> filter_by(X.yearID == 2009)
           >> drop(X.yearID)
          )
teams09.head()
# Out:
#      teamID                  name                         park
# 2595    ARI  Arizona Diamondbacks                  Chase Field
# 2596    ATL        Atlanta Braves                 Turner Field
# 2597    BAL     Baltimore Orioles  Oriole Park at Camden Yards
# 2598    BOS        Boston Red Sox               Fenway Park II
# 2599    CHA     Chicago White Sox          U.S. Cellular Field

# %%
len(runs)*len(teams09)
# Out:
# 900

# %%
runs_per_team09_new = (runs 
                       >> left_join(teams09, by='teamID')
                       >> drop(X.teamID))
runs_per_team09_new.head()
# Out:
#    total_runs                  name                         park
# 0         720  Arizona Diamondbacks                  Chase Field
# 1         735        Atlanta Braves                 Turner Field
# 2         741     Baltimore Orioles  Oriole Park at Camden Yards
# 3         872        Boston Red Sox               Fenway Park II
# 4         724     Chicago White Sox          U.S. Cellular Field

# %%
runs_per_team09_new.shape
# Out:
# (30, 3)

# %% [markdown]
# ## Don't worry about speed until it matters!
#
# * I don't emphasize speed most of the time.
# * In this case, either approach was nearly instant.
# * Still ... `join`s are *so dangerous* that I make an exception here!

# %% [markdown]
# ## <font color="red"> Exercise 1 </font>
#
# Determine all the players that have hit more than 100 home runs in a season.  The final table should include the players proper name, as well as the team name.
#
# **Hint:** You will need join the files listed below.  To get credit for this exercise, use the join methods presented above.

# %%
files = ("./data/baseball/core/Batting.csv", 
         "./data/baseball/core/People.csv",
         "./data/baseball/core/Teams.csv")

# %%
batting = pd.read_csv("./data/baseball/core/Batting.csv")
batting.head(2)
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI   SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0  8.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# 1  1.0   4  0.0  NaN  NaN NaN NaN   0.0
#
# [2 rows x 22 columns]

# %%
people = pd.read_csv("./data/baseball/core/People.csv")
people.head(2)
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
#
#   birthCity  deathYear  deathMonth  deathDay  ... nameLast    nameGiven  \
# 0    Denver        NaN         NaN       NaN  ...  Aardsma  David Allan
# 1    Mobile        NaN         NaN       NaN  ...    Aaron  Henry Louis
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# 0  215.0   75.0    R      R  2004-04-06  2015-08-23  aardd001  aardsda01
# 1  180.0   72.0    R      R  1954-04-13  1976-10-03  aaroh101  aaronha01
#
# [2 rows x 24 columns]

# %%
teams = pd.read_csv("./data/baseball/core/Teams.csv")
teams.head(20)
# Out:
#     yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP  \
# 0     1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24
# 1     1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16
# 2     1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15
# 3     1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8
# 4     1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14
# 5     1871  NaN    PH1      PNA   NaN     1  28    NaN  21   7  ...  13
# 6     1871  NaN    RC1      ROK   NaN     9  25    NaN   4  21  ...  14
# 7     1871  NaN    TRO      TRO   NaN     6  29    NaN  13  15  ...  22
# 8     1871  NaN    WS3      OLY   NaN     4  32    NaN  15  15  ...  20
# 9     1872  NaN    BL1      BLC   NaN     2  58    NaN  35  19  ...  22
# 10    1872  NaN    BR1      ECK   NaN     9  29    NaN   3  26  ...   9
# 11    1872  NaN    BR2      BRA   NaN     6  37    NaN   9  28  ...  15
# 12    1872  NaN    BS1      BNA   NaN     1  48    NaN  39   8  ...  44
# 13    1872  NaN    CL1      CFC   NaN     7  22    NaN   6  16  ...  17
# 14    1872  NaN    MID      MAN   NaN     8  24    NaN   5  19  ...  11
# 15    1872  NaN    NY2      NNA   NaN     3  56    NaN  34  20  ...  33
# 16    1872  NaN    PH1      PNA   NaN     4  47    NaN  30  14  ...  20
# 17    1872  NaN    TRO      TRO   NaN     5  25    NaN  15  10  ...   9
# 18    1872  NaN    WS3      OLY   NaN    10   9    NaN   2   7  ...   7
# 19    1872  NaN    WS4      NAT   NaN    11  11    NaN   0  11  ...   2
#
#        FP                     name                               park  \
# 0   0.834     Boston Red Stockings                South End Grounds I
# 1   0.829  Chicago White Stockings            Union Base-Ball Grounds
# 2   0.818   Cleveland Forest Citys       National Association Grounds
# 3   0.803     Fort Wayne Kekiongas                     Hamilton Field
# 4   0.840         New York Mutuals           Union Grounds (Brooklyn)
# 5   0.845   Philadelphia Athletics           Jefferson Street Grounds
# 6   0.821    Rockford Forest Citys  Agricultural Society Fair Grounds
# 7   0.845           Troy Haymakers                 Haymakers' Grounds
# 8   0.850      Washington Olympics                   Olympics Grounds
# 9   0.830       Baltimore Canaries                     Newington Park
# 10  0.803        Brooklyn Eckfords                      Union Grounds
# 11  0.810       Brooklyn Atlantics                 Capitoline Grounds
# 12  0.875     Boston Red Stockings                South End Grounds I
# 13  0.816   Cleveland Forest Citys       National Association Grounds
# 14  0.804    Middletown Mansfields             Mansfield Club Grounds
# 15  0.868         New York Mutuals           Union Grounds (Brooklyn)
# 16  0.858   Philadelphia Athletics           Jefferson Street Grounds
# 17  0.861           Troy Haymakers                 Haymakers' Grounds
# 18  0.786      Washington Olympics                   Olympics Grounds
# 19  0.774     Washington Nationals                  Nationals Grounds
#
#     attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0          NaN  103   98       BOS             BS1          BS1
# 1          NaN  104  102       CHI             CH1          CH1
# 2          NaN   96  100       CLE             CL1          CL1
# 3          NaN  101  107       KEK             FW1          FW1
# 4          NaN   90   88       NYU             NY2          NY2
# 5          NaN  102   98       ATH             PH1          PH1
# 6          NaN   97   99       ROK             RC1          RC1
# 7          NaN  101  100       TRO             TRO          TRO
# 8          NaN   94   98       OLY             WS3          WS3
# 9          NaN  106  102       BAL             BL1          BL1
# 10         NaN   87   96       ECK             BR1          BR1
# 11         NaN  115  122       BRA             BR2          BR2
# 12         NaN  105  100       BOS             BS1          BS1
# 13         NaN   96  100       CLE             CL1          CL1
# 14         NaN   98  103       MAN             MID          MID
# 15         NaN   93   92       NYU             NY2          NY2
# 16         NaN  102  100       ATH             PH1          PH1
# 17         NaN  101  100       TRO             TRO          TRO
# 18         NaN   94   98       OLY             WS3          WS3
# 19         NaN  129  141       NAT             WS4          WS4
#
# [20 rows x 48 columns]

# %%
Big_batters=(batting
    >> select(X.playerID,X.teamID,X.HR,X.yearID)
    #>> group_by(X.yearID)
    #>> mutate(Max_HR = X.HR.max())
    #>> filter_by(X.playerID == "bondsba01")
    >> filter_by(X.HR >50)
)
Big_batters
# Out:
#          playerID teamID  HR  yearID
# 18534    ruthba01    NYA  54    1920
# 19054    ruthba01    NYA  59    1921
# 22271    ruthba01    NYA  60    1927
# 22801    ruthba01    NYA  54    1928
# 23980   wilsoha01    CHN  56    1930
# 24654    foxxji01    PHA  58    1932
# 27767   greenha01    DET  58    1938
# 33002   kinerra01    PIT  51    1947
# 33104    mizejo01    NY1  51    1947
# 34154   kinerra01    PIT  54    1949
# 37834    mayswi01    NY1  51    1955
# 38467   mantlmi01    NYA  52    1956
# 41674   mantlmi01    NYA  54    1961
# 41676   marisro01    NYA  61    1961
# 44657    mayswi01    SFN  52    1965
# 54762   fostege01    CIN  52    1977
# 67723   fieldce01    DET  51    1990
# 74879   mcgwima01    OAK  52    1996
# 75835   griffke02    SEA  56    1997
# 77079   griffke02    SEA  56    1998
# 77405   mcgwima01    SLN  70    1998
# 77752    sosasa01    CHN  66    1998
# 78721   mcgwima01    SLN  65    1999
# 79069    sosasa01    CHN  63    1999
# 80768   bondsba01    SFN  73    2001
# 81095   gonzalu01    ARI  57    2001
# 81689   rodrial01    TEX  52    2001
# 81786    sosasa01    CHN  64    2001
# 83012   rodrial01    TEX  57    2002
# 83167   thomeji01    CLE  52    2002
# 86623   jonesan01    ATL  51    2005
# 87903   howarry01    PHI  58    2006
# 88247   ortizda01    BOS  54    2006
# 89784   rodrial01    NYA  54    2007
# 92931   bautijo02    TOR  54    2010
# 97328   davisch02    BAL  53    2013
# 103526  judgeaa01    NYA  52    2017
# 104124  stantmi03    MIA  59    2017
# 105901  alonspe01    NYN  53    2019

# %% [markdown]
# ## There are no players with over 100 runs in a season

# %%
intermediate=(Big_batters 
 >> left_join(people, by= "playerID")
 >> select(X.playerID, X.teamID, X.HR, X.nameLast, X.nameGiven,X.yearID))
 #>> inner_join(teams, by= "teamID")
 #>> select(X.playerID, X.teamID, X.HR, X.nameLast, X.nameGiven, X.name, X.W,X.L))
intermediate
# Out:
#      playerID teamID  HR   nameLast               nameGiven  yearID
# 0    ruthba01    NYA  54       Ruth           George Herman    1920
# 1    ruthba01    NYA  59       Ruth           George Herman    1921
# 2    ruthba01    NYA  60       Ruth           George Herman    1927
# 3    ruthba01    NYA  54       Ruth           George Herman    1928
# 4   wilsoha01    CHN  56     Wilson            Lewis Robert    1930
# 5    foxxji01    PHA  58       Foxx             James Emory    1932
# 6   greenha01    DET  58  Greenberg          Henry Benjamin    1938
# 7   kinerra01    PIT  51      Kiner         Ralph McPherran    1947
# 8    mizejo01    NY1  51       Mize             John Robert    1947
# 9   kinerra01    PIT  54      Kiner         Ralph McPherran    1949
# 10   mayswi01    NY1  51       Mays           Willie Howard    1955
# 11  mantlmi01    NYA  52     Mantle          Mickey Charles    1956
# 12  mantlmi01    NYA  54     Mantle          Mickey Charles    1961
# 13  marisro01    NYA  61      Maris            Roger Eugene    1961
# 14   mayswi01    SFN  52       Mays           Willie Howard    1965
# 15  fostege01    CIN  52     Foster           George Arthur    1977
# 16  fieldce01    DET  51    Fielder             Cecil Grant    1990
# 17  mcgwima01    OAK  52    McGwire              Mark David    1996
# 18  griffke02    SEA  56    Griffey          George Kenneth    1997
# 19  griffke02    SEA  56    Griffey          George Kenneth    1998
# 20  mcgwima01    SLN  70    McGwire              Mark David    1998
# 21   sosasa01    CHN  66       Sosa          Samuel Peralta    1998
# 22  mcgwima01    SLN  65    McGwire              Mark David    1999
# 23   sosasa01    CHN  63       Sosa          Samuel Peralta    1999
# 24  bondsba01    SFN  73      Bonds             Barry Lamar    2001
# 25  gonzalu01    ARI  57   Gonzalez             Luis Emilio    2001
# 26  rodrial01    TEX  52  Rodriguez      Alexander Enmanuel    2001
# 27   sosasa01    CHN  64       Sosa          Samuel Peralta    2001
# 28  rodrial01    TEX  57  Rodriguez      Alexander Enmanuel    2002
# 29  thomeji01    CLE  52      Thome            James Howard    2002
# 30  jonesan01    ATL  51      Jones           Andruw Rudolf    2005
# 31  howarry01    PHI  58     Howard              Ryan James    2006
# 32  ortizda01    BOS  54      Ortiz           David Americo    2006
# 33  rodrial01    NYA  54  Rodriguez      Alexander Enmanuel    2007
# 34  bautijo02    TOR  54   Bautista            Jose Antonio    2010
# 35  davisch02    BAL  53      Davis         Christopher Lyn    2013
# 36  judgeaa01    NYA  52      Judge             Aaron James    2017
# 37  stantmi03    MIA  59    Stanton  Giancarlo Cruz-Michael    2017
# 38  alonspe01    NYN  53     Alonso            Peter Morgan    2019

# %%
(intermediate 
    >> left_join(teams, by=["teamID","yearID"])
    >> select(X.playerID, X.teamID, X.HR_x, X.nameLast, X.nameGiven, X.name,X.yearID)
)
# Out:
#      playerID teamID  HR_x   nameLast               nameGiven  \
# 0    ruthba01    NYA    54       Ruth           George Herman
# 1    ruthba01    NYA    59       Ruth           George Herman
# 2    ruthba01    NYA    60       Ruth           George Herman
# 3    ruthba01    NYA    54       Ruth           George Herman
# 4   wilsoha01    CHN    56     Wilson            Lewis Robert
# 5    foxxji01    PHA    58       Foxx             James Emory
# 6   greenha01    DET    58  Greenberg          Henry Benjamin
# 7   kinerra01    PIT    51      Kiner         Ralph McPherran
# 8    mizejo01    NY1    51       Mize             John Robert
# 9   kinerra01    PIT    54      Kiner         Ralph McPherran
# 10   mayswi01    NY1    51       Mays           Willie Howard
# 11  mantlmi01    NYA    52     Mantle          Mickey Charles
# 12  mantlmi01    NYA    54     Mantle          Mickey Charles
# 13  marisro01    NYA    61      Maris            Roger Eugene
# 14   mayswi01    SFN    52       Mays           Willie Howard
# 15  fostege01    CIN    52     Foster           George Arthur
# 16  fieldce01    DET    51    Fielder             Cecil Grant
# 17  mcgwima01    OAK    52    McGwire              Mark David
# 18  griffke02    SEA    56    Griffey          George Kenneth
# 19  griffke02    SEA    56    Griffey          George Kenneth
# 20  mcgwima01    SLN    70    McGwire              Mark David
# 21   sosasa01    CHN    66       Sosa          Samuel Peralta
# 22  mcgwima01    SLN    65    McGwire              Mark David
# 23   sosasa01    CHN    63       Sosa          Samuel Peralta
# 24  bondsba01    SFN    73      Bonds             Barry Lamar
# 25  gonzalu01    ARI    57   Gonzalez             Luis Emilio
# 26  rodrial01    TEX    52  Rodriguez      Alexander Enmanuel
# 27   sosasa01    CHN    64       Sosa          Samuel Peralta
# 28  rodrial01    TEX    57  Rodriguez      Alexander Enmanuel
# 29  thomeji01    CLE    52      Thome            James Howard
# 30  jonesan01    ATL    51      Jones           Andruw Rudolf
# 31  howarry01    PHI    58     Howard              Ryan James
# 32  ortizda01    BOS    54      Ortiz           David Americo
# 33  rodrial01    NYA    54  Rodriguez      Alexander Enmanuel
# 34  bautijo02    TOR    54   Bautista            Jose Antonio
# 35  davisch02    BAL    53      Davis         Christopher Lyn
# 36  judgeaa01    NYA    52      Judge             Aaron James
# 37  stantmi03    MIA    59    Stanton  Giancarlo Cruz-Michael
# 38  alonspe01    NYN    53     Alonso            Peter Morgan
#
#                       name  yearID
# 0         New York Yankees    1920
# 1         New York Yankees    1921
# 2         New York Yankees    1927
# 3         New York Yankees    1928
# 4             Chicago Cubs    1930
# 5   Philadelphia Athletics    1932
# 6           Detroit Tigers    1938
# 7       Pittsburgh Pirates    1947
# 8          New York Giants    1947
# 9       Pittsburgh Pirates    1949
# 10         New York Giants    1955
# 11        New York Yankees    1956
# 12        New York Yankees    1961
# 13        New York Yankees    1961
# 14    San Francisco Giants    1965
# 15         Cincinnati Reds    1977
# 16          Detroit Tigers    1990
# 17       Oakland Athletics    1996
# 18        Seattle Mariners    1997
# 19        Seattle Mariners    1998
# 20     St. Louis Cardinals    1998
# 21            Chicago Cubs    1998
# 22     St. Louis Cardinals    1999
# 23            Chicago Cubs    1999
# 24    San Francisco Giants    2001
# 25    Arizona Diamondbacks    2001
# 26           Texas Rangers    2001
# 27            Chicago Cubs    2001
# 28           Texas Rangers    2002
# 29       Cleveland Indians    2002
# 30          Atlanta Braves    2005
# 31   Philadelphia Phillies    2006
# 32          Boston Red Sox    2006
# 33        New York Yankees    2007
# 34       Toronto Blue Jays    2010
# 35       Baltimore Orioles    2013
# 36        New York Yankees    2017
# 37           Miami Marlins    2017
# 38           New York Mets    2019
